# %% [markdown]
# ### Start a Spark Context

# %%
if 'sc' not in locals():
    from pyspark.context import SparkContext
    from pyspark.sql.context import SQLContext
    from pyspark.sql.session import SparkSession
    
    sc = SparkContext()
    sqlContext = SQLContext(sc)
    spark = SparkSession(sc)

# %%
from pyspark.sql.functions import regexp_replace
from pyspark.ml.feature import Tokenizer, StopWordsRemover

# %%
import pandas as pd
import os
import sys
import gzip

# %% [markdown]
# ### Loading Data

# %%
### data path
path0 = 'Data/'
filename = 'reviews_Amazon_Instant_Video_5.json.gz'
path = path0 + filename

# %%
### function to extract and parse the data

def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

df = getDF(path)

# %%
df.shape
# Out:
# (37126, 9)

# %%
df.head()
# Out:
#        reviewerID        asin                    reviewerName helpful  \
# 0  A11N155CW1UV02  B000H00VBQ                        AdrianaM  [0, 0]
# 1  A3BC8O2KCL29V2  B000H00VBQ                         Carol T  [0, 0]
# 2   A60D5HQFOTSOM  B000H00VBQ  Daniel Cooper "dancoopermedia"  [0, 1]
# 3  A1RJPIGRSNX4PW  B000H00VBQ                  J. Kaplan "JJ"  [0, 0]
# 4  A16XRPF40679KG  B000H00VBQ                   Michael Dobey  [1, 1]
#
#                                           reviewText  overall  \
# 0  I had big expectations because I love English ...      2.0
# 1  I highly recommend this series. It is a must f...      5.0
# 2  This one is a real snoozer. Don't believe anyt...      1.0
# 3  Mysteries are interesting.  The tension betwee...      4.0
# 4  This show always is excellent, as far as briti...      5.0
#
#                           summary  unixReviewTime   reviewTime
# 0      A little bit boring for me      1399075200   05 3, 2014
# 1           Excellent Grown Up TV      1346630400   09 3, 2012
# 2           Way too boring for me      1381881600  10 16, 2013
# 3     Robson Green is mesmerizing      1383091200  10 30, 2013
# 4  Robson green and great writing      1234310400  02 11, 2009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37126 entries, 0 to 37125
# Data columns (total 9 columns):
# reviewerID        37126 non-null object
# asin              37126 non-null object
# reviewerName      36797 non-null object
# helpful           37126 non-null object
# reviewText        37126 non-null object
# overall           37126 non-null float64
# summary           37126 non-null object
# unixReviewTime    37126 non-null int64
# reviewTime        37126 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 2.8+ MB

# %%
from contractions import CONTRACTION_MAP

import re
def expand_contractions(text, contraction_mapping=CONTRACTION_MAP):
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                                if contraction_mapping.get(match)\
                                else contraction_mapping.get(match.lower())                       
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction
        
    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text

expand_contractions("Y'all can't expand contractions I'd think")
# Out:
# 'You all cannot expand contractions I would think'

# %%
# Create a Spark DataFrame from a Pandas DataFrame
# spark = SparkSession.builder.appName('pandasToSparkDF').getOrCreate()
from pyspark.sql.types import StructType, StructField
from pyspark.sql.types import DoubleType, IntegerType, StringType, FloatType, DoubleType

mySchema = StructType([ 
                        StructField("reviewerID", StringType(), True)\
                       ,StructField("asin", StringType(), True)\
#                        StructField("reviewerName", StringType(), True)\
                       ,StructField("helpful", StringType(), True)\
                       ,StructField("reviewText", StringType(), True)\
                       ,StructField("overall", FloatType(), True)\
                       ,StructField("summary", StringType(), True)\
                       ,StructField("unixReviewTime", IntegerType(), True)\
                       ,StructField("reviewTime", DoubleType(), True)
                      ])
sms = spark.createDataFrame(df.drop(columns=['reviewerName']))

# %%
# Remove punctuation (REGEX provided) and numbers
wrangled = sms.withColumn('reviewText', regexp_replace(sms.reviewText, '[_():;,.!?\\-"/&#\'*]', ' '))
wrangled = wrangled.withColumn('reviewText', regexp_replace(wrangled.reviewText,'\d', ' '))

# Merge multiple spaces
wrangled = wrangled.withColumn('reviewText', regexp_replace(wrangled.reviewText, ' +', ' '))

# Remove Contraction 
# from pyspark.sql.functions import explode
# from pyspark.sql.functions import udf, array
# expand_contractions_udf = udf(lambda z: expand_contractions(z), StringType())
# wrangled = wrangled.withColumn('reviewText', expand_contractions_udf(wrangled.reviewText))
# Split the text into words
wrangled = Tokenizer(inputCol='reviewText', outputCol='words').transform(wrangled)

wrangled.show(4, truncate=False)
# Out:
# +--------------+----------+-------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+---------------------------+--------------+-----------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |reviewerID    |asin      |helpful|reviewText                                                                                                                                                                           |overall|summary                    |unixReviewTime|reviewTime |words                                                                                                                                                                                                                |
# +--------------+----------+-------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+---------------------------+--------------+-----------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |A11N155CW1UV02|B000H00VBQ|[0, 0] |I had big expectations because I love English TV in particular Investigative and detective stuff but this guy is really boring It didn t appeal to me at all                         |2.0    |A little bit boring for me |1399075200    |05 3, 2014 |[i, had, big, expectations, because, i, love, english, tv, in, particular, investigative, and, detective, stuff, but, this, guy, is, really, boring, it, didn, t, appeal, to, me, at, all]                           |
# |A3BC8O2KCL29V2|B000H00VBQ|[0, 0] |I highly recommend this series It is a must for anyone who is yearning to watch grown up television Complex characters and plots to keep one totally involved Thank you Amazin Prime |5.0    |Excellent Grown Up TV      |1346630400    |09 3, 2012 |[i, highly, recommend, this, series, it, is, a, must, for, anyone, who, is, yearning, to, watch, grown, up, television, complex, characters, and, plots, to, keep, one, totally, involved, thank, you, amazin, prime]|
# |A60D5HQFOTSOM |B000H00VBQ|[0, 1] |This one is a real snoozer Don t believe anything you read or hear it s awful I had no idea what the title means Neither will you                                                    |1.0    |Way too boring for me      |1381881600    |10 16, 2013|[this, one, is, a, real, snoozer, don, t, believe, anything, you, read, or, hear, it, s, awful, i, had, no, idea, what, the, title, means, neither, will, you]                                                       |
# |A1RJPIGRSNX4PW|B000H00VBQ|[0, 0] |Mysteries are interesting The tension between Robson and the tall blond is good but not always believable She often seemed uncomfortable                                             |4.0    |Robson Green is mesmerizing|1383091200    |10 30, 2013|[mysteries, are, interesting, the, tension, between, robson, and, the, tall, blond, is, good, but, not, always, believable, she, often, seemed, uncomfortable]                                                       |
# +--------------+----------+-------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+---------------------------+--------------+-----------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 4 rows

# %%
from pyspark.ml.feature import StopWordsRemover, HashingTF, IDF

# Remove stop words.
wrangled = StopWordsRemover(inputCol='words', outputCol='terms')\
      .transform(wrangled)

# # Apply the hashing trick
# wrangled = HashingTF(inputCol='terms', outputCol='hash', numFeatures=1024)\
#       .transform(wrangled)

# # Convert hashed symbols to TF-IDF
# tf_idf = IDF(inputCol='hash', outputCol='features')\
#       .fit(wrangled).transform(wrangled)
      
# tf_idf.select('terms', 'features').show(4, truncate=False)

# %%
from pyspark.sql.functions import explode
wrangled.select(explode("words")).distinct().show(1111)
# Out:
# +-------------------+
# |                col|
# +-------------------+
# |              still|
# |               hope|
# |             biting|
# |               some|
# |          involving|
# |              trail|
# |                few|
# |              those|
# |               earl|
# |           everyday|
# |          standards|
# |        requirement|
# |          connected|
# |             harder|
# |              salma|
# |            embrace|
# |             outfit|
# |        interaction|
# |           tortured|
# |             travel|
# |          traveling|
# |              ginzu|
# |           brackets|
# |            finales|
# |         creativity|
# |              oscar|
# |            letdown|
# |             poetry|
# |             spared|
# |              spoil|
# |          sidelined|
# |             doubts|
# |        handicapped|
# |              inner|
# |                art|
# |         lieutenant|
# |          recognize|
# |            jeebies|
# |       terrifically|
# |          viewpoint|
# |             deftly|
# |             online|
# |          theorists|
# |              cures|
# |              hoess|
# |            degrade|
# |                bys|
# |             voyage|
# |             freaks|
# |      gratification|
# |            insipid|
# |               didi|
# |            blossom|
# |            jewelry|
# |               gags|
# |           priority|
# |            sharona|
# |         concluding|
# |             filing|
# |           randomly|
# |             honcho|
# |         charachter|
# |             wields|
# |            elevate|
# |            persist|
# |             bazaar|
# |              juimp|
# |      youthfullness|
# |               guts|
# |          arguments|
# |            blaster|
# |        transaction|
# |           spoiling|
# |           cheyenne|
# |           incoming|
# |              anime|
# |       melodramtaic|
# |          imitation|
# |          machinist|
# |            nichole|
# |        montenegrot|
# |            flashed|
# |             ransom|
# |                dts|
# |               iffy|
# |              input|
# |           cautious|
# |            palicki|
# |             waters|
# |     paralinguistic|
# |        unavoidably|
# |            mmorpgs|
# |             patton|
# |              effer|
# |         electrical|
# |         likelihood|
# |              monte|
# |             thwart|
# |              pools|
# |             manesi|
# |              mammy|
# |          indicator|
# |            lyrical|
# |         circulates|
# |           currents|
# |       masturbating|
# |           harasser|
# |           antennae|
# |            tarnish|
# |          stilettos|
# |               gacy|
# |           pacquiao|
# |            inchuck|
# |        desecration|
# |           tripping|
# |           recoment|
# |             suzhou|
# |         occidental|
# |         indigenous|
# |             shroud|
# |             brands|
# |      indoctrinated|
# |           toamazon|
# |           zemeckis|
# |          torchwood|
# |          destitute|
# |              hanna|
# |               wtih|
# |         abruptness|
# |             leonor|
# |              aleck|
# |            barrier|
# |           debunked|
# |        transmitted|
# |                fog|
# |             caynon|
# |   welfareincluding|
# |             marrow|
# |           newlywed|
# |         distancing|
# |               rabe|
# |       transference|
# |          sufficent|
# |            bidders|
# |             vortex|
# |          moviesbah|
# |            kiyoshi|
# |              meloy|
# |         roundabout|
# |           driscoll|
# |              trina|
# |        whobelieves|
# |              poppy|
# |           painters|
# |            marxism|
# |              tosar|
# |           lacrosse|
# |            pitcher|
# |           carnegie|
# |             tonnes|
# |               bava|
# |           inverted|
# |         rejuvenate|
# |           ubruptly|
# |            flaccid|
# |         commanders|
# |         misogynist|
# |       inflammatory|
# |        suspensions|
# |           `capture|
# |              carlo|
# |           medicare|
# |           briefest|
# |           nowmaybe|
# |               jamb|
# |              crest|
# |        picturewise|
# |            courted|
# |            reviled|
# |          librarian|
# |             frumpy|
# |            melodic|
# |          neverseen|
# |           guernsey|
# |           heinrich|
# |          playrooms|
# |          digitized|
# |            skrulls|
# |           pagenais|
# |            balding|
# |ifmiffyandmonkeyhad|
# |           stuttery|
# |              whopo|
# |              oohhh|
# |       workcombined|
# |           crawlies|
# |               vies|
# |           vladimir|
# |                zig|
# |          woderfull|
# |            benanti|
# |            phillis|
# |                itt|
# |      socialization|
# |           ignominy|
# |            hightly|
# |             gloria|
# |         seperation|
# |            beyound|
# |         paramedics|
# |             tillis|
# |       accumulation|
# |         didgeridoo|
# |            hitched|
# |               usms|
# |            implore|
# |            moreand|
# |             mooney|
# |          andcoming|
# |     americabecause|
# |              splif|
# |            tattler|
# |          forgetful|
# |               yoki|
# |           didactic|
# |            off]mel|
# |               foxy|
# |             stiyle|
# |              feign|
# |             avoide|
# |           yokohama|
# |            hoechin|
# |            prieval|
# |                mgs|
# |        disassemble|
# |          probabaly|
# |           madelene|
# |           nicotine|
# |             slaver|
# |         girlkiller|
# |           fiscally|
# |          timetable|
# |             ecause|
# |          geneology|
# |      ethnocentrism|
# |           beccause|
# |             wigged|
# |              turks|
# |              poach|
# |               pant|
# |         westernyee|
# |        ineluctably|
# |             todrag|
# |         mendelsohn|
# |        sparklingly|
# |          witticism|
# |              brant|
# |             kennex|
# |         reanimated|
# |     wonderlandwith|
# |        lovableness|
# |              okies|
# |             cowell|
# |           jettison|
# |              xfile|
# |           diehards|
# |            inanity|
# |              exept|
# |             hunnum|
# |           pushback|
# |          schaeffer|
# |             lazslo|
# |         strawberry|
# |             ltimos|
# |            familia|
# |             taissa|
# |              hobbs|
# |         telletubby|
# |         television|
# |              often|
# |               bone|
# |            painted|
# |           laughing|
# |           slightly|
# |             worked|
# |              allas|
# |               tons|
# |            slaying|
# |              parts|
# |             filled|
# |              staff|
# |          actresses|
# |          partially|
# |              oddly|
# |              scifi|
# |           positive|
# |             taking|
# |              vocal|
# |           received|
# |                col|
# |            zealots|
# |        conspicuous|
# |              macho|
# |              drain|
# |            goodman|
# |            include|
# |        brilliantly|
# |           pleasing|
# |              rolls|
# |             soliel|
# |            grisham|
# |          twobennet|
# |         productive|
# |           richness|
# |           stations|
# |         wrongdoing|
# |              rears|
# |             nights|
# |             absurd|
# |            tilting|
# |          operation|
# |             speedy|
# |           smelling|
# |              irwin|
# |          cartesian|
# |         fraternity|
# |   characterization|
# |         speculated|
# |           watchers|
# |              hardy|
# |             sequel|
# |             launch|
# |           motorist|
# |            enlists|
# |        conclusions|
# |       surrealistic|
# |             blasts|
# |          glimpsing|
# |       manipulative|
# |           shrunken|
# |            highest|
# |         variations|
# |        expaninding|
# |                yrs|
# |           rebelled|
# |            auction|
# |             mugger|
# |              mafia|
# |             leland|
# |           beverage|
# |           sneaking|
# |         broadcasts|
# |             calvin|
# |               lucy|
# |              cabal|
# |            spheres|
# |             weirdo|
# |               tivo|
# |       conversation|
# |            redeems|
# |             wheels|
# |          expertise|
# |           defeated|
# |              hurry|
# |             gadget|
# |           smuggest|
# |                ciy|
# |        distributor|
# |           cozyness|
# |          overseers|
# |             column|
# |              flees|
# |            krueger|
# |              dough|
# |           thegenre|
# |            valerie|
# |                ioa|
# |            brusque|
# |       jurisdiction|
# |              verzy|
# |           withheld|
# |             marley|
# |              gemma|
# |              booms|
# |           noticing|
# |         indictment|
# |           ungarded|
# |               wilf|
# |         photograph|
# |            wrestle|
# |          registers|
# |            portant|
# |             import|
# |  coorporationsbent|
# |              crust|
# |     zombie\monster|
# |        necromancer|
# |        predominant|
# |          alazraqui|
# |              tseng|
# |           retailer|
# |              gleek|
# |       grotesquerie|
# |           anyplace|
# |         plasticity|
# |            hobothe|
# |            pensive|
# |          fraternal|
# |           unmanned|
# |               tosh|
# |           chestnut|
# |          plausibly|
# |             swipes|
# |          kobiyashi|
# |          sceptical|
# |              socio|
# |            humbled|
# |              fakey|
# |            morrell|
# |           cesspool|
# |          quarreled|
# |               livy|
# |              hench|
# |              qaeda|
# |           lullabys|
# |           drinkers|
# |              lyall|
# |            rebirth|
# |       narcissistic|
# |             spurts|
# |         outsmarted|
# |           cuttings|
# |            waltzed|
# |            drizzle|
# |         miscreants|
# |       comeuppances|
# |              zilla|
# |             repels|
# |          phenomina|
# |             unwise|
# |       monosyllabic|
# |          initiated|
# |            nasties|
# |         crocodiles|
# |             japans|
# |                fas|
# |             [simon|
# |             occult|
# |             pluses|
# |         em>session|
# |           idiocies|
# |            peolple|
# |          carryover|
# |          fittingly|
# |             tester|
# |        emancipated|
# |              snips|
# |        enhancement|
# |            routing|
# |          goofballs|
# |               beeb|
# |            makkena|
# |        coeducation|
# |            `native|
# |            candane|
# |              sigma|
# |              `goes|
# |              staes|
# |         regularity|
# |           herschel|
# |           excluded|
# |         humanistic|
# |         exercution|
# |          delirious|
# |              thoms|
# |             detain|
# |           deushane|
# |             endgam|
# |               fawn|
# |          construed|
# |            racking|
# |              scorn|
# |            clawing|
# |            wilfred|
# |       pharmacology|
# |            bulimia|
# |           outgoing|
# |         craigslist|
# |         undeterred|
# |            felacio|
# |             papist|
# |             rueful|
# |        unflappable|
# |           conflate|
# |          egomaniac|
# |           tomohawk|
# |              lmfao|
# |        astronautic|
# |               oook|
# |          surveying|
# |           squatchy|
# |            lapides|
# |          children]|
# |             combed|
# |         outmanuver|
# |            spyware|
# |             gropes|
# |        polkadotted|
# |          cognizant|
# |             upends|
# |       andersonvery|
# |             powaah|
# |            skyfall|
# |                tse|
# |         whiteboard|
# |         headliners|
# |              mists|
# |             kickin|
# |           indonesa|
# |           loyalest|
# |               witt|
# |          bafoonery|
# |          flammable|
# |        sermonizing|
# |           funnyits|
# |                 ]]|
# |        appreaciate|
# |            boreman|
# |         convection|
# |               aubv|
# |          entireity|
# |          detesting|
# |           kirkmans|
# |              atlee|
# |               s%$t|
# |          sedatives|
# |          damnation|
# |          cattyness|
# |           beinecke|
# |             nausea|
# |              latly|
# |    funnycharacters|
# |             varuda|
# |   counterbalancing|
# |            allthis|
# |         commending|
# |             imothe|
# |               oike|
# |       farsicameron|
# |                rey|
# |              watch|
# |          chemistry|
# |              paddy|
# |               lent|
# |                 ld|
# |         cultivates|
# |         terrorists|
# |              equal|
# |            arguing|
# |         schoolgirl|
# |            jungles|
# |                map|
# |              peaks|
# |           avengers|
# |             hockey|
# |             growth|
# |         definately|
# |           galactic|
# |              genii|
# |               coin|
# |           premiere|
# |         afterwards|
# |         evaluation|
# |            seroyan|
# |          directors|
# |                cia|
# |              cable|
# |         transfered|
# |              harry|
# |           belonged|
# |            explain|
# |         surrounded|
# |  inappropriateness|
# |             garces|
# |               lies|
# |             thuday|
# |          sentences|
# |             arches|
# |             arisen|
# |          schruette|
# |           ruggiero|
# |             heated|
# |          oblivious|
# |             posing|
# |           passtime|
# |           disaster|
# |             greece|
# |            achieve|
# |           nighters|
# |            chapuys|
# |           reaaally|
# |             alison|
# |              hires|
# |              plane|
# |     preconceptions|
# |       generallythe|
# |               wasa|
# |            airlock|
# |         childhoods|
# |              kacey|
# |              viper|
# |        deliverance|
# |             dunnit|
# |          frustrate|
# |             belzer|
# |           covertly|
# |              toils|
# |             breezy|
# |            herders|
# |           disarray|
# |               drip|
# |              decay|
# |               dung|
# |             kenzie|
# |           hometown|
# |                der|
# |      boothmichaela|
# |               cook|
# |              haunt|
# |            gladise|
# |                hub|
# |          womanizer|
# |              chalk|
# |       terrifyingly|
# |           muscular|
# |           sundance|
# |              seaon|
# |           tellling|
# |          demeaning|
# |           inhances|
# |          competive|
# |           goldfish|
# |             bierce|
# |          dickerson|
# |                ryo|
# |        agonizingly|
# |            pinging|
# |              brane|
# |          detailing|
# |    underprivileged|
# |              deeds|
# |            candice|
# |           postpone|
# |             newton|
# |           humaness|
# |         flittering|
# |       impressively|
# |       indiscretion|
# |          venusians|
# |                amp|
# |              hamks|
# |          australia|
# |              murky|
# |             knopfe|
# |             futile|
# |         undergoing|
# |     choreographers|
# |         disrupting|
# |           keyboard|
# |          kittenish|
# |               zahf|
# |             aryans|
# |             charts|
# |        unendurable|
# |              lords|
# |                itv|
# |         gargantuan|
# |             dusted|
# |         stronghold|
# |              brett|
# |          noteriety|
# |          travelled|
# |            cousins|
# |               farr|
# |             sandal|
# |     dramasatellite|
# |          stockholm|
# |       doctorreboot|
# |        carolreboot|
# |            unloads|
# |            phallic|
# |       refrigerator|
# |              javou|
# |          shielding|
# |             youngs|
# |             clover|
# |        misbehavior|
# |                lex|
# |           logician|
# |              vibes|
# |          retriever|
# |            schtick|
# |           gorlacon|
# |          sprawling|
# |           boulders|
# |              sawed|
# |           sensuthe|
# |               lark|
# |      modernization|
# |      characterizes|
# |           disprove|
# |            bravura|
# |      unjustifiably|
# |            vinegar|
# |           differed|
# |             boogie|
# |             basest|
# |        nicelooking|
# |              wench|
# |           doctrine|
# |          retainers|
# |          intercept|
# |             homies|
# |         droppingly|
# |        vigilantism|
# |           wothless|
# |          eponymous|
# |               sail|
# |            chnnnel|
# |          assigning|
# |            sheffer|
# |           reactors|
# |           cleverer|
# |         tawdriness|
# |           aquifers|
# |       auditedfrank|
# |          warburton|
# |           fletcher|
# |            rockies|
# |        neutralized|
# |             tootie|
# |              baulk|
# |       marginalized|
# |        backsliding|
# |             saliva|
# |            mysterv|
# |         ruggedness|
# |            huddled|
# |     roadtripwinner|
# |              hasom|
# |      distributions|
# |           infusion|
# |  englishrecomended|
# |            `genius|
# |                ffm|
# |            gaylord|
# |      notmycupoftea|
# |             kanima|
# |             ivanir|
# |              endup|
# |              abets|
# |                 ey|
# |          recomment|
# |        overreaches|
# |               limb|
# |         carpoolers|
# |         vegetables|
# |         ctenosaura|
# |             dimple|
# |               gere|
# |      informerswith|
# |            surives|
# |         swimsuited|
# |             pazzis|
# |                 ct|
# |              katic|
# |             walden|
# |           americon|
# |            onderon|
# |              looky|
# |                coz|
# |              souks|
# |             demoys|
# |                 f@|
# |              noser|
# |         criticised|
# |          breaching|
# |              posen|
# |              good+|
# |            speeces|
# |          maintence|
# |          worldview|
# |     transmutations|
# |               gall|
# |                ove|
# |               emts|
# |           capsules|
# |      unconsummated|
# |         senatorial|
# |           nebbishy|
# |            versace|
# |        everlasting|
# |            espheni|
# |        blasphemous|
# |     predicamentand|
# |         beauitiful|
# |          greenland|
# |       wereterrific|
# |             yetbut|
# |           tampered|
# |            probalt|
# |     rastafarianism|
# |             wearer|
# |                jpg|
# |          aroundfor|
# |           patinkin|
# |           flaherty|
# |            doppelg|
# |            baldies|
# |            dickson|
# |           mamelove|
# |             haurer|
# |                dnd|
# |            portays|
# |         villarreal|
# |           tinkered|
# |        fruitlessly|
# |                dmv|
# |          mitigates|
# |         signposted|
# |               alia|
# |           massella|
# |             dorset|
# |             jislam|
# |       connecticutt|
# |       emancipation|
# |         incredable|
# |             mackie|
# |            getters|
# |   overcompensating|
# |                eph|
# |          character|
# |               film|
# |             julian|
# |               anti|
# |             covert|
# |               slow|
# |           romantic|
# |          cardboard|
# |          extension|
# |            divulge|
# |                hao|
# |            suicide|
# |          typically|
# |              sucre|
# |            simmers|
# |          morbidity|
# |            horatio|
# |            stomach|
# |             podell|
# |                 du|
# |            prevent|
# |            rapists|
# |                 en|
# |                 ye|
# |             arenas|
# |        perspective|
# |            blooded|
# |         undetected|
# |         approached|
# |         opposition|
# |           roadside|
# |            servant|
# |       incompatible|
# |              juicy|
# |             intact|
# |            kendall|
# |        etertaining|
# |         accusation|
# |         unsolvable|
# |           reworked|
# |               dive|
# |                psa|
# |         gymnastics|
# |               shut|
# |            buffers|
# |      incorrectness|
# |      pilotmeetsthe|
# |           spending|
# |           gasoline|
# |           colleges|
# |            ravaged|
# |           portugal|
# |             ronnie|
# |         abundantly|
# |           reviting|
# |              tires|
# |       heartrending|
# |             boomer|
# |           outlawed|
# |                pcs|
# |       cliffhangers|
# |              oomph|
# |          intricate|
# |         settlement|
# |                det|
# |              stove|
# |            bonding|
# |             duties|
# |             wagner|
# |            harshyl|
# |            envious|
# |             fudged|
# |                jar|
# |              parks|
# |             violet|
# |              yearn|
# |           optimist|
# |        verbalizing|
# |          countries|
# |         decomposed|
# |             hating|
# |         hellraiser|
# |             midway|
# |            graboid|
# |             valley|
# |          mirroring|
# |                ira|
# |       predilection|
# |         aboutbryan|
# |       chemotherapy|
# |           amateurs|
# |               farm|
# |            bubbler|
# |              yells|
# |            showers|
# |         footprints|
# |             dishes|
# |               bros|
# |            sandman|
# |              goofs|
# |          admitting|
# |            oakland|
# |               papa|
# |           globally|
# |          clemenson|
# |                nat|
# |          contrasts|
# |          omissions|
# |           isabella|
# |              peels|
# |             danzel|
# |               babe|
# |          declining|
# |           `pigeons|
# |           clownish|
# |      mountains]pee|
# |             blazed|
# |            cannons|
# |          landmarks|
# |       constabulary|
# |         disclaimer|
# |         telegraphs|
# |         manmanages|
# |      spontaneously|
# |       dissociative|
# |           audacity|
# |             garuda|
# |        vandervoort|
# |          overthrow|
# |          sanitized|
# |              madea|
# |           exploded|
# |             bakula|
# |              lithe|
# |              coral|
# |              attia|
# |       extravaganza|
# |              dancy|
# |             `adult|
# |          foregoing|
# |         succinctly|
# |            yourway|
# |           lovelies|
# |           jailbird|
# |          relocates|
# |              dawns|
# |      disintegrated|
# |            flowers|
# |            acerbic|
# |           hercules|
# |            sawalha|
# |          biography|
# |               surf|
# |          ceaucescu|
# |          macintosh|
# |          `inspired|
# |              brite|
# |             kitano|
# |           sannokai|
# |              terra|
# |               tows|
# |              evere|
# |                tri|
# |          backhills|
# |       misdemeanors|
# |               yada|
# |        intricacies|
# |       forbrydelsen|
# |             ascend|
# |                doi|
# |           pipeline|
# |         scurrilous|
# |           catapult|
# |    associationkyle|
# |         exploiters|
# |           baystill|
# |        accentuated|
# |         hoardensis|
# |           arbitary|
# |               nows|
# |           elitists|
# |     herinteraction|
# |    thnfvtgntgbthtb|
# |            overawe|
# |            schlitz|
# |            flaming|
# |         butexisted|
# |            nearest|
# |              karel|
# |              wolfe|
# |              forks|
# |             mucker|
# |          alcaltraz|
# |             louisa|
# |          camcorder|
# |              abeth|
# |          joustings|
# |               turf|
# |           dreamand|
# |          timepiece|
# |         languishes|
# |            peacham|
# |           readneck|
# |           anorexia|
# |             shanyn|
# |             drowsy|
# |             suplid|
# |           peepshow|
# |              vodoo|
# |           cruising|
# |          sparklers|
# |            twosome|
# |       interstellar|
# |              imaan|
# |           verbatim|
# |             posses|
# |        impatiently|
# |           knowlege|
# |              goode|
# |       schoolhouses|
# |           obsolete|
# |      sorcerergreat|
# |       splatterings|
# |             gamine|
# |         providence|
# |            huertas|
# |              benzy|
# |      provocatively|
# |           deadshot|
# |          monsignor|
# |         stinkeroos|
# |            dissing|
# |                nev|
# |            janelle|
# |              davie|
# |          fairbanks|
# |             darrin|
# |              bench|
# |            blubber|
# |             fallin|
# |             cables|
# |            forword|
# |            farmira|
# |             borneo|
# |   maryexcisiononly|
# |            cornies|
# |           abrahams|
# |              gerry|
# |          touristas|
# |                 wy|
# |               outr|
# |           lonergan|
# |          ostensive|
# |         falsehoods|
# |           lifeboat|
# |         hatchlings|
# |              coked|
# |             sprits|
# |         seniormost|
# |         diagologue|
# |              totes|
# |        globemaster|
# |              pygmy|
# |           parlayed|
# |              madox|
# |            ezekiel|
# |        teleportred|
# |           vaporize|
# |              >>>>>|
# |              nonso|
# +-------------------+
# only showing top 1111 rows

# %%
import torch
